# %% [markdown]
# # 01 - Preprocessing Demonstration
#
# This notebook demonstrates the preprocessing pipeline developed for the
# research project:
#
# "Sentiment Analysis of Player Reactions to Monetisation Systems in Gacha
# Games Using Natural Language Processing"
#
# The notebook uses synthetic demonstration data only.
#
# No Reddit research data are included or processed in this demonstration.
#
# ## Objectives
#
# This notebook demonstrates:
#
# 1. Loading the input dataset
# 2. Inspecting the data
# 3. Handling missing values
# 4. Removing duplicate records
# 5. Applying text preprocessing
# 6. Inspecting the processed output
#
# The preprocessing pipeline is intended for later application to an
# ethically approved and authorised research dataset.

# %%
import sys
from pathlib import Path

import pandas as pd

# Allow imports from the project src directory
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.preprocessing import preprocess_text

# %%
DATA_PATH = PROJECT_ROOT / "data" / "sample_data.csv"

df = pd.read_csv(DATA_PATH)

print(f"Dataset shape: {df.shape}")
df.head()
# Out:
# Dataset shape: (9, 3)
#                                                 text               game  \
# 0  The pity system is really helpful and makes pu...     Genshin Impact
# 1  The banner rates feel terrible and I spent far...     Genshin Impact
# 2   I saved enough primogems for the next character.     Genshin Impact
# 3  I actually like the pity system because I know...  Honkai: Star Rail
# 4  The cost of pulls is ridiculous for free to pl...  Honkai: Star Rail
#
#   sentiment
# 0  Positive
# 1  Negative
# 2   Neutral
# 3  Positive
# 4  Negative

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       9 non-null      str
#  1   game       9 non-null      str
#  2   sentiment  9 non-null      str
# dtypes: str(3)
# memory usage: 348.0 bytes

# %%
df.isnull().sum()
# Out:
# text         0
# game         0
# sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["processed_text"] = df["text"].apply(preprocess_text)

df[["text", "processed_text"]].head(10)
# Out:
#                                                 text  \
# 0  The pity system is really helpful and makes pu...
# 1  The banner rates feel terrible and I spent far...
# 2   I saved enough primogems for the next character.
# 3  I actually like the pity system because I know...
# 4  The cost of pulls is ridiculous for free to pl...
# 5                   The new banner starts next week.
# 6  The pity system makes the banner feel much fai...
# 7                I hate how expensive the pulls are.
# 8  I am waiting to see the next banner before spe...
#
#                                       processed_text
# 0  the pity system is really helpful and makes pu...
# 1  the banner rates feel terrible and i spent far...
# 2   i saved enough primogems for the next character.
# 3  i actually like the pity system because i know...
# 4  the cost of pulls is ridiculous for free to pl...
# 5                   the new banner starts next week.
# 6  the pity system makes the banner feel much fai...
# ...

# %%
print("Preprocessing demonstration completed successfully.")
# Out:
# Preprocessing demonstration completed successfully.
